# %%
import os
from PIL import Image
import pypdfium2 as pdfium
from io import BytesIO
from easyocr import Reader

# %%
! pip install easyocr
# Out:
# Collecting easyocr
#   Using cached easyocr-1.7.1-py3-none-any.whl (2.9 MB)
# Requirement already satisfied: torch in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from easyocr) (2.0.1)
# Collecting torchvision>=0.5 (from easyocr)
#   Downloading torchvision-0.17.2-cp38-cp38-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 3.1 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting opencv-python-headless (from easyocr)
#   Using cached opencv_python_headless-4.9.0.80-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.6 MB)
# Requirement already satisfied: scipy in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from easyocr) (1.10.1)
# Requirement already satisfied: numpy in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from easyocr) (1.24.3)
# Requirement already satisfied: Pillow in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from easyocr) (9.5.0)
# Collecting scikit-image (from easyocr)
#   Using cached scikit_image-0.21.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.9 MB)
# Collecting python-bidi (from easyocr)
#   Using cached python_bidi-0.4.2-py2.py3-none-any.whl (30 kB)
# Requirement already satisfied: PyYAML in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from easyocr) (6.0)
# Collecting Shapely (from easyocr)
#   Using cached shapely-2.0.3-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
# Collecting pyclipper (from easyocr)
#   Using cached pyclipper-1.3.0.post5-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.whl (682 kB)
# Collecting ninja (from easyocr)
#   Using cached ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
# Collecting torch (from easyocr)
#   Downloading torch-2.2.2-cp38-cp38-manylinux1_x86_64.whl (755.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.5/755.5 MB 4.0 MB/s eta 0:00:00m eta 0:00:010:00:03
# Requirement already satisfied: filelock in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from torch->easyocr) (3.12.2)
# Collecting typing-extensions>=4.8.0 (from torch->easyocr)
#   Downloading typing_extensions-4.11.0-py3-none-any.whl (34 kB)
# Requirement already satisfied: sympy in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from torch->easyocr) (3.1)
# Requirement already satisfied: jinja2 in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from torch->easyocr) (3.1.2)
# Requirement already satisfied: fsspec in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from torch->easyocr) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch->easyocr)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch->easyocr)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch->easyocr)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch->easyocr)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch->easyocr)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch->easyocr)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch->easyocr)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch->easyocr)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch->easyocr)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch->easyocr)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch->easyocr)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Collecting triton==2.2.0 (from torch->easyocr)
#   Using cached triton-2.2.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch->easyocr)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 8.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: six in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from python-bidi->easyocr) (1.16.0)
# Collecting imageio>=2.27 (from scikit-image->easyocr)
#   Using cached imageio-2.34.0-py3-none-any.whl (313 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Using cached tifffile-2023.7.10-py3-none-any.whl (220 kB)
# Collecting PyWavelets>=1.1.1 (from scikit-image->easyocr)
#   Using cached PyWavelets-1.4.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Requirement already satisfied: packaging>=21 in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from scikit-image->easyocr) (23.1)
# Collecting lazy_loader>=0.2 (from scikit-image->easyocr)
#   Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from jinja2->torch->easyocr) (2.1.2)
# Requirement already satisfied: mpmath>=0.19 in /home/kaushal/selfLearning/venvSL/lib/python3.8/site-packages (from sympy->torch->easyocr) (1.3.0)
# Installing collected packages: pyclipper, ninja, typing-extensions, triton, tifffile, Shapely, PyWavelets, python-bidi, opencv-python-headless, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, lazy_loader, imageio, scikit-image, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision, easyocr
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.7.1
#     Uninstalling typing_extensions-4.7.1:
#       Successfully uninstalled typing_extensions-4.7.1
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1
#     Uninstalling torch-2.0.1:
#       Successfully uninstalled torch-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# xformers 0.0.20 requires torch==2.0.1, but you have torch 2.2.2 which is incompatible.
# Successfully installed PyWavelets-1.4.1 Shapely-2.0.3 easyocr-1.7.1 imageio-2.34.0 lazy_loader-0.4 ninja-1.11.1.1 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105 opencv-python-headless-4.9.0.80 pyclipper-1.3.0.post5 python-bidi-0.4.2 scikit-image-0.21.0 tifffile-2023.7.10 torch-2.2.2 torchvision-0.17.2 triton-2.2.0 typing-extensions-4.11.0
#
# [notice] A new release of pip is available: 23.1.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
def convert_pdf_to_images(file_path, scale=300/72):
    
    pdf_file = pdfium.PdfDocument(file_path)  
    page_indices = [i for i in range(len(pdf_file))]
    
    renderer = pdf_file.render(
        pdfium.PdfBitmap.to_pil,
        page_indices = page_indices, 
        scale = scale,
    )
    
    list_final_images = [] 
    
    for i, image in zip(page_indices, renderer):
        
        image_byte_array = BytesIO()
        image.save(image_byte_array, format='jpeg', optimize=True)
        image_byte_array = image_byte_array.getvalue()
        list_final_images.append(dict({i:image_byte_array}))
    
    return list_final_images

convert_pdf_to_images = convert_pdf_to_images('fund-factsheet-for-september-2023.pdf')

# %%
language_reader = Reader(["en"])
def extract_text_with_easyocr(list_dict_final_images):
    
    image_list = [list(data.values())[0] for data in list_dict_final_images]
    image_content = []
    
    for index, image_bytes in enumerate(image_list):
        
        image = Image.open(BytesIO(image_bytes))
        raw_text = language_reader.readtext(image)
        raw_text = "\n".join([res[1] for res in raw_text])
                       
        image_content.append(raw_text)
    
    return "\n".join(image_content)

text_with_easy_ocr = extract_text_with_easyocr(convert_pdf_to_images)
print(text_with_easy_ocr)
# Out:
# THE
# 0ICICI
# PRUJENTIAL
# PRUEENT
# MUTUAL
# FUND
# FACT SHEET
# September 30,.2023
# Build your investments with the
# growing manufacturing theme
# Invest in
# ICICI Prudential
# Manufacturing Fund
# To invest; contact your Mutual Fund Distributor
# IPRUTOUCH
# WWWI
# iciciprumf.com
# ICICI Prudential Manufacturing Fund (An Open Ended Equity Scheme following manufacturing theme:)
# is suitable for investors who are seeking*=
# Investors
# Long term wealth creation
# understand that
# An open ended equity scheme that aims to provide capital appreciation by investing in equity and
# %6,
# their principal
# 8
# equity related securities of companies engaged in manufacturing theme:
# g
# will be at
# 3
# 3
# High risk
# #Investors should consult their financial advisers if in doubt about whether the product is suitable for them:
# The Risk-o-meter specified above will be evaluated and updated on a monthly basis Please refer https:IIwww icicipruamccom/news-and-updateslall-news
# for more details on scheme riskometers_
# Mutual Fund investments are subject to market risks, read all scheme related documents carefully:
# App
# RISKOMETER
# SCHEME
# moderate ,
# moderately
# high
# 1
# 1
# Very
# INDEX
# Fund Name
# Category
# Description
# Page No
# Economic Overview and Market Outlook
# 5-12
# Equity Schemes
# ICICI Prudential Bluechip Fund
# Large Cap Fund
# An open ended equity scheme predominantly investing in large cap stocks
# 13
# ICICI Prudential Flexicap Fund
# Flexi Cap
# An open ended dynamic equity scheme investing across large cap; mid cap &
# 14
# small cap stocks
# ICICI Prudential Large & Mid Cap Fund
# Large & Mid Cap
# An open ended equity scheme investing in both large cap and mid cap stocks
# 15-16
# Fund
# ICICI Prudential Multicap Fund
# Multicap Fund
# An open ended equity scheme investing across large cap, mid cap, small cap stocks
# 17-18
# ICICI Prudential India Opportunities Fund
# Thematic
# An open ended equity scheme following special situations theme
# 19
# ICICI Prudential Value Discovery Fund
# Value Fund
# An open ended equity scheme following
# a value investment strategy
# 20
# ICICI Prudential Long Term Equity Fund
# Equity Linked
# An open Ended Equity Scheme with Tax Saving advantage
# 21
# (Tax Saving)
# Savings Scheme
# (ELSS)
# ICICI Prudential Focused Equity Fund
# Focused Fund
# An open ended equity scheme investing in maximum 30 stocks
# 22
# ICICI Prudential Dividend Yield Equity Fund
# Dividend Yield
# An open ended equity scheme predominantly investing in dividend yielding stocks
# 23
# Fund
# ICICI Prudential PSU Equity Fund
# Thematic
# An open-ended equity scheme following the PSU theme
# 24
# ICICI Prudential Midcap Fund
# Mid Cap Fund
# An open ended equity scheme predominantly investing in mid cap stocks
# 25
# ICICI Prudential Smallcap Fund
# Small Cap Fund
# An open ended equity scheme predominantly investing in small cap stocks
# 26
# ICICI Prudential Banking & Financial
# Services Fund
# Sectoral
# An open ended equity scheme investing in banking & financial services sector
# 27
# ICICI Prudential FMCG Fund
# Sectoral
# An open ended equity scheme investing in FMCG sector
# 28
# ICICI Prudential Technology Fund
# Sectoral
# An open ended equity scheme investing in technology and related sectors
# 29
# ICICI Prudential Business Cycle Fund
# Thematic
# An open ended equity scheme following business
# based investing theme
# 30
# ICICI Prudential Transportation and Logistics Fund Thematic
# An open ended equity scheme following transportation and logistics theme
# 31
# ICICI Prudential Housing Opportunities Fund
# Thematic
# An open ended equity scheme following housing theme
# 32
# ICICI Prudential ESG Fund
# Thematic
# (An open ended equity scheme investing in companies identified based on the
# 33
# Environmental, Social and Governance (ESG) theme)
# ICICI Prudential Pharma Healthcare and
# Thematic
# An Open Ended Equity Scheme following Pharma, Healthcare, Diagnostic and
# Diagnostics (PH.D) Fund
# allied Theme:
# 34
# ICICI Prudential Exports and Services Fund
# Thematic
# An open ended equity scheme following exports and services theme
# 35
# ICICI Prudential Infrastructure Fund
# Thematic
# An open ended equity scheme following infrastructure theme
# 36
# ICICI Prudential Manufacturing Fund
# Thematic
# An Open Ended Equity Scheme following manufacturing theme
# 37
# ICICI Prudential MNC Fund
# Thematic
# An open ended Equity Scheme following MNC theme
# 38
# ICICI Prudential Bharat Consumption Fund
# Thematic
# An open ended scheme investing in companies engaged in consumption and
# 39
# consumption related activities:
# ICICI Prudential Commodities Fund
# Thematic
# An open ended equity scheme investing primarily in commodities and commodity
# 40
# related sectors_
# ICICI Prudential US Bluechip Equity Fund
# Thematic
# An open ended equity scheme following bluechip companies listed in US
# 41-42
# ICICI Prudential Quant Fund
# Thematic
# An open ended equity scheme following Quant based investing theme
# 43
# ICICI Prudential Innovation Fund
# Thematic
# An open ended equity scheme following innovation theme
# 44
# Hybrid Schemes
# ICICI Prudential Equity & Debt Fund
# Aggressive
# An open ended hybrid scheme investing predominantly in equity and equity
# 45-46
# Hybrid Fund
# related instruments
# ICICI Prudential Equity
# Arbitrage Fund
# Arbitrage Fund
# An open ended scheme investing in arbitrage opportunities
# 47-48
# ICICI Prudential Balanced Advantage Fund
# Dynamic Asset
# An open ended dynamic asset allocation fund
# 49-50
# Allocation/Balanced
# Advantage Fund
# ICICI Prudential Equity Savings Fund
# Equity Savings
# An open ended scheme investing in equity, arbitrage and debt
# 51-52
# Fund
# ICICI Prudential Regular Savings Fund
# Conservative
# An open ended hybrid scheme investing predominantly in debt instruments
# 53-54
# Hybrid Fund
# ICICI Prudential Multi-Asset Fund
# Multi Asset
# An open ended scheme investing in multi assets
# 55-56
# Allocation
# 2
# cycles
# INDEX
# Fund Name
# Category
# Description
# Page No)
# Fund Of Funds Schemes
# ICICI Prudential Passive Multi-Asset Fund of Funds Other Scheme
# An open ended fund of funds scheme investing in equity, debt;
# and global index
# fundslexchange traded funds
# 57
# ICICI Prudential Thematic Advantage Fund (FOF)
# Other Scheme
# An open ended fund of funds scheme investing predominantly in Sectorall
# Thematic schemes:
# 58
# ICICI Prudential Passive Strategy Fund (FOF)
# Other Scheme
# An open ended fund of funds scheme investing predominantly in Units of domestic
# Equity Exchange Traded Funds
# 59
# ICICI Prudential India Equity FOF
# Other Scheme
# An Open ended Fund of Funds investing in units of equity oriented schemes_
# 60
# ICICI Prudential BHARAT 22 FOF
# Other Scheme
# An open ended fund of funds scheme investing in BHARAT 22 ETF
# 61
# ICICI Prudential Global Advantage Fund (FOF)
# Other Scheme
# An open ended Fund of Funds scheme predominantly investing in mutual fund
# schemes
# ETFs that invest in international markets:)
# 62
# ICICI Prudential Strategic Metal and Energy Equity
# Other Scheme
# An Open ended fund of fund scheme investing in Units/shares of First Trust Strategic
# Fund of Fund
# Metal and Energy Equity UCITS Fund
# 63
# ICICI Prudential Global Stable Equity
# Other Scheme
# Open ended Fund of Funds Scheme investing in overseas mutual fund schemes
# Fund (FOF)
# which invest in stable companies globally
# 64
# ICICI Prudential Asset Allocator Fund (FOF)
# Other Scheme
# An open ended fund of funds scheme investing in equity oriented schemes_
# debt oriented schemes and
# ETFslschemes:
# 65
# ICICI Prudential Income Optimizer Fund (FOF)
# Other Scheme
# An open ended fund of funds scheme predominantly investing in debt oriented
# schemes and may also invest in equity & hybrid schemes
# 66
# ICICI Prudential Debt Management Fund (FOF)
# Other Scheme
# An open ended fund of funds scheme investing predominantly in debt
# oriented schemes:
# ICICI Prudential Nifty 100 Low Volatility 30
# Other Scheme
# An open ended fund of funds scheme investing in ICICI Prudential Nifty 100
# ETF FOF
# Low Volatility 30 ETF
# 68
# ICICI Prudential Nifty Alpha Low
# Volatility 30
# Other Scheme
# An open ended fund of funds scheme investing in ICICI Prudential
# Alpha
# ETF FOF
# Low- Volatility 30 ETF
# 69
# ICICI Prudential s&P BSE 500 ETF FOF
# Other Scheme
# An open ended fund of funds scheme investing in ICICI Prudential S&P BSE 500 ETF
# 70
# ICICI Prudential Regular Gold Savings Fund (FOF)
# Other Scheme
# An Open Ended Fund of Funds scheme investing in ICICI Prudential Gold ETF
# 71
# ICICI Prudential Silver ETF Fund of Fund
# Other Scheme
# An open ended fund of fund scheme investing in units of ICICI Prudential Silver ETF
# 72
# Debt Schemes
# ICICI Prudential Overnight Fund
# Overnight Fund
# An open ended debt scheme investing in overnight securities
# 73
# ICICI Prudential Liquid Fund
# Liquid Fund
# Investment in Debt and money market securities with maturity of upto 91 days only
# 74
# ICICI Prudential Money Market Fund
# Money Market
# An open ended debt scheme investing in money market instruments
# 75
# Fund
# ICICI Prudential Ultra Short Term Fund
# Ultra Short
# An open ended ultra-short term debt scheme investing in instruments such that
# 76
# Duration Fund
# the Macaulay duration of the portfolio is between 3 months and 6 months:
# ICICI Prudential Savings Fund
# Low Duration Fund
# An open ended debt scheme with Macaulay Duration between 6
# 12 months
# 77
# ICICI Prudential Floating Interest Fund
# Floater Fund
# An open ended debt scheme predominantly investing in floating rate instruments
# 78
# ICICI Prudential Short Term Fund
# Short Duration
# An open ended short term debt scheme investing in instruments such that the
# 79
# Fund
# Macaulay duration of the portfolio is between 1 Year and 3 Years:
# ICICI Prudential Bond Fund
# Medium to Long
# An open ended debt scheme with Macaulay Duration between 4 _ 7 years
# 80
# Duration Fund
# ICICI Prudential Corporate Bond Fund
# Corporate Bond
# An open ended debt scheme predominantly investing in AA+ and above rated
# 81
# Fund
# corporate bonds
# ICICI Prudential Banking & PSU Debt Fund
# Banking & PSU
# An open ended debt scheme predominantly investing in Debt instruments of banks,
# 82
# Fund
# Public Sector Undertakings, Public Financial Institutions
# ICICI Prudential Credit Risk Fund
# Credit Risk Fund
# An open ended debt scheme predominantly investing in AA and below rated
# corporate bonds:
# 83-84
# ICICI Prudential Medium Term Bond Fund
# Medium Duration
# An Open Ended medium term debt scheme investing in instruments such that the
# 85
# Fund
# Macaulay duration of the portfolio is between 3 Years and 4 Years The Macaulay
# duration of the portfolio is 1 Year to
# 4 years under anticipated adverse situation_
# ICICI Prudential Long Term Bond Fund
# Long Duration
# An open ended debt scheme with Macaulay duration greater than 7 years
# 86
# Fund
# ICICI Prudential AII Seasons Bond Fund
# Dynamic Bond
# An open ended dynamic debt scheme investing across duration
# 87
# ICICI Prudential Gilt Fund
# Gilt Fund
# An open ended debt scheme investing in government securities across maturity
# 88
# ICICI Prudential Constant Maturity Gilt Fund
# Gilt Fund with
# An open ended debt scheme investing in government securities having a
# 89
# 10-year Constant
# constant maturity of 10 Years
# Duration
# 3
# gold
# gold
# Nifty
# INDEX
# Fund Name
# Category
# Description
# Page No
# Solution Oriented Schemes
# ICICI Prudential Child Care Fund (Gift Plan)
# Solution oriented
# scheme
# Diversified Long Term Child Benefit Oriented Plan
# 90
# ICICI Prudential Retirement Fund
# Solution Oriented Scheme
# An open ended Retirement Solution Oriented Scheme
# 91-94
# Closed Ended Equity Schemes
# ICICI Prudential Long Term Wealth
# Closed Ended
# Equity Linked Savings Scheme (ELSS) with a statutory lock in of 3 years and
# Enhancement Fund
# tax benefit
# 95
# Other Details
# Annexure Of Quantitative Indicators For Debt Fund
# 96
# Annexure For All Potential Risk Class
# 97-98
# Fund Details Annexure
# 99-106
# Annexure for Returns of all the Schemes
# 107-116
# Fund Manager Detail
# 117-118
# Systematic Investment Plan (SIP) of Select Schemes
# 119-123
# Performance of Select Schemes
# Annexure
# 124
# Annexure
# 125
# IDCW History for all Schemes
# 125-130
# Investment Objective of all the schemes
# 131-133
# Schedule 1: One Liner Definitions
# 134
# Schedule 2: How To Read Factsheet
# 135-136
# Statutory Details & Risk Factors
# 137
# ECONOMIC
# OVERVIEW
# O
# Global Economic Growth
# Growth trends in developed economies
# Growth projections for 2023
# 25
# 6.0%
# 2.2
# 2.0
# 4.0%
# 2
# 8
# 1.5
# 2.0%
# 1
# 1
# 1.0
# 0.o%
# 0
# 0.5
# -2.0%
# US
# Eurozone
# UK
# Japan
# 0.0
# US
# Euro zone
# UK
# Japan
# Q2 CY 2022
# Q3 CY 2022
# Q4 CY 2022
# 1Q1 CY 2023
# Q2 CY 2023
# IMF World Economic Outlook; july 2023
# OECD Economic outlook; September 2023
# Sources: CRSISLResearch, Financialnews websites, International Monetary Fund (IMF) , Organisation for Economic Co-operation and Development (OECD)
# GDP oftheUS grew anannualised 2.1% in the Q2CY23 as compared with upwardly revised growth of 2.2% in Q1CY23
# The Eurozone economy expanded 0.5% on-year in the second quarter of CY 2023,slightly below growth of 0.6% and easing from expansion of 1.1% in the previous
# quarter:
# The UK GDP grew 0.6% on-yearin Q2CY23,as compared with upwardly revised expansion of 0.5% in the previous quarter:
# The Japanese economy grew 4.8% on an annualised basis in the second quarter of CY 2023, compared with downwardly revised growth of 3.2% in the previous
# quarter:
# Source: CRISIL Research: GDP: Gross Domestic Product; US: Unites States, UK- United Kingdom, CY: Calendar Year
# Global Central Bank Highlights
# US Fed keptits interestrates steadyin the range of 5.25%-5.5% atits Sep-23 policy meet:
# However; the central bank stiffened its hawkish stance, with
# a further rate increase
# 6.0%
# 5.50% 5.25%
# projected by the end of the year and monetary policy kept significantly tighter through
# 5.0%
# 50%
# 50%
# 2024thanpreviously expected:
# 2
# 4.0%
# 3.50%
# ECB raisedits keyinterestrate to an all-time record high of 4.50%
# 4.25% in Sep-23.
# 3.0%
# 2.50%
# BoE at its Sep-23 meeting held its policy interest rate at 5.25%, its first pause in policy
#
# 2.0%
# tightening in nearly twoyears
# Bo] maintained its
# short-term interest rate at -0.1% and that of
# 10-year bond yields
# 1.0%
# 0.3%
# 0.3%
# ataround O% inits Sep-23 meeting:
# 0.0%
# 0.0%
# The one-year loan prime rate (LPR) by PBoC was kept unchanged at a record low of
# 0%
# -0.1%
# 0.1%
# 0.1%
# 3.45%, whilethefive-yearrate, areferencefor mortgages, waskeptat 4.2%.
# 2021
# 2022
# 2023*
# Source: CRISILResearch: US: United States, Fed: Federal Reserve System of US,ECB: European
# US
# UK
# Japan
# Eurozone
# Central Bank, BoE: Bank of England;
# PBoC: People's Bank of China, BoJ: Bank of Japan
# Source: CRISIL Research; *Data as of September 2023
# Global Bond Yields
# US Treasury prices declined sharply in Sept-23. The yield on the 10-year Treasury bond
# settled at 4.57% on September 29,2023,comparedto 4.09%on August31,2023.
# 6.00
# The yield rose significantly and touched a multi-year high during the month; driven by
# expectations that the US Federal Reserve (US Fed) may keep interest rates higher for
# 5.00
# longer: Strong economic data and official comments further supported this market
# sentiment.
# 4.00
# Orders for US factory goods declined 2.1% in July-23, while ISM services PMI remained
# 3.00
# strong:
#
# 2.00
# Yields rose further after Fed Governor Christopher Waller said the central bank need not
# changerates any time soon:
# 1.00
# Hotter-than-expected US retail sales data contributed to a further rise in yields Retail
# 0.00
# sales in the US advanced 0.6% on-month in
# -23,higher than a downwardly revised
# 0.5%rise in July-23_
# -1.00
# ~
# Bond prices declined afterthe US Fed signalled another ratehike beforethe end of 2023.
# 7
# 1
# 1
# 1
# 8
# 1
# 1
# {
# 1
# The US central bank held interest rates steady, as was widely expected, and indicated
# 3
# 3
# thatits benchmark overnight interest rate may be lifted one more time this yearto
# peak
# 5.50-5.75%
# US 10-Year G-sec Yield
# UK 10-Year G-sec Yield
# Expectations that the Fed would keep interest rates higher for longer than initially
# Germany 10-Year G-sec Yield
# Japan 10-Year G-sec Yield
# anticipated also keptbond prices under pressure
# However; bond prices witnessed some
# after weaker-than-expected economic
# growth and labour market data dimmed expectations that the Fed will further raise
# interest rates laterthisyear:
# Source: Crisil Research
# Yields also slipped after data showed Personal Consumption Expenditures (PCE) price
# index inflation came in line with expectations andjobless claims fell:
# Gains in yields were also halted on profit-booking and investors exercising caution ahead
# oftherelease of
# USeconomic data:
# Source: CRISIL
# Research:
# GDP:
# Gross
# domestic product;
# US: Unites States, UK:
# United
# Kingdom, PCE: Personal Consumption Expenditure; Fed: Federal Reserve System of US, ISM:
# Institute of Supply Management; PMI: Purchasing Managers Index
# None ofthe aforesaid recommendations are based onany assumptions These are purely forreference and the investors are requested to consulttheir financial advisors before investing:
# 5
# 1.8
# from
# key
# Aug-
# gains
# key
# ECONOMIC
# OVERVIEW
# 77
# India Growth
# Growth trend
# Growth projections for 2023
# 25
# 21.6
# IMF World Economic Outlook, July
# OECD Economic outlook; September
# 2023 update
# 2023
# 2
# 20
# 8.0
# 15
# 13.2
# 1
# 10
# 9.1
# 7.8
# 6.1
# 5.2
# 6.3
# 6.1
# 6.0
# 4.1
# 5
# 2.5
# 8
# 8
# L
# 4.0
# -5
# 0
# -10
# 6.6
# 8
# 2.0
# MXW
# 0.0
# Source: Mospi nicin, IMF, OECD
# India's GDP growth rose 7.8% intheQ1FY24,from 6.1% growthin Q4Y23
# In terms of gross value added,the economy grew 8%vs 6.5%
# Industry
# Q1FY24 Growth %
# Q4FY23 Growth %
# AgricultureForestry & Fishing_
# 3.5
# 5.5
# Mining & Quarrying
# 5.8
# 4.3
# Manufacturing_
# 4.7
# 4.5
# Electricity Gas,Water Supply & Other Utility Service
# 2.9
# 6.9
# Construction
# 7.9
# 10.4
# Trade, Hotels, Transport; Communication & Services relatedto Broadcasting
# 9.2
# 9.1
# Financial, Real Estate & Professional Services
# 12.2
# 7.1
# Public Administration, Defense & Other Services
# 7.9
# 3.1
# Slowing global growth had impacted India's GDP last fiscal as exports and industrial activity were sluggish: The impact may be deeper this fiscal as global economic
# activity decelerates further as reflected in low exports. Domestic demand was supportive for growth last fiscal:
# While domestic indicators remain steady and
# structural positives are getting built up,managing global frontmay be a key challenge for Indian GDP
# Source: CRISIL Research. GDP: Gross Domestic Product, FY: Financial Year
# Other Major Indicators
# CPI inflation eased to 6.83% on-year in August-23 from 7.44% on-
# India's industrial production rose to 5.7% on-year in July-23 from
# year in July-23
# 3.7% on-year in June-23
# 9
# 6.83
# 6.0
# 20
# 8
# 5.0
# 7
# 4.0
# {
# 6
# 3.0
# 2
# 15
# 8
# 5
# 2.0
# g
# 2
# 4
# 1.0
# 0
# 3
# 0.0
# 10
# 5.70
# 1
# 2
# ~20
# ]
# 1
# 0
# -3.0
# 6
# 5
# 1127712777238823772471237
# 2
# Real interest rate (RHS)
# CPI Inflation (LHS)
# 10-year G-sec yield (LHS)
# 3
# 1
# 1
# 1
# 1
# 1
# 3
# 8
# 1
# 3
# 3
# 3
# Source: MOSPI; Office of Economic Advisor; IHS Markit
# 6
# 3
# ECONOMIC
# OVERVIEW
# Output of eight core sectors grew 12.4% on year in August-23,
# S&P Global manufacturing PMI rose to 58.6 in August-23 from
# compared with 8.4% on-year in July-23
# 57.7 in July-23, while services PMI declined to 60.1 from 62.3
# 15
# Purchasing Managers' Index (PMI)
# 12.4
# 70
# 2
# 3
# m
# 0
# 8
# 5 8
# 3
# 8
# 8 6
# 3
# 8
# n %
# 6
# 8
# 2
# 60
# 3 4
# # #
# #
# 8
# 10
# 8.3
# 8.4
# 50
# 1
# 40
# {
# 4.2
# 4.2
# 4.6
# 5.2
# 30
# 8
# 20
# 0.7
# 10
# 1
# 3
# 3
# 1
# 8
# 8
# 3
# 3
# 3
# 3
# 1
# 3
# 3
# -10
# 3
# 8
# 3
# 3
# 3
# 8
# 3
# 3
# 3
# 3
# 3
# 3
# 1
# Manufacturing PMI
# Services PMI
# Source: MOSPI, Office of Economic Advisor,IHS Markit
# Economic indicator heat map
# Indicators
# 23
# July 23
# June 23
# 23
# Apr 23
# Mar-23
# Industrial Sector
# Manufacturing PMI
# 58.6
# 57.7
# 57.8
# 58.7
# 57.2
# 56.4
# Infra
# Core
# 12.10%
# 8.40%
# 8.30%
# 5.20%
# 4.60%
# 4.20%
# Rail Freight Traffic (Loading in million tonnes)
# 127.16
# 124
# 123.1
# 134
# 126.5
# 397.6
# Rail Passenger Traffic  (in million)
# 590.65
# 569.1
# 563.1
# 589.3
# 546.9
# 582.9
# Consumer Economy
# Passenger vehicle sales (thousands)
# 313.72
# 302.52
# 327.95
# 288.37
# 284.27
# 337.9
# Two-wheeler sales (thousands)
# 1566.59
# 1282.05
# 1330.83
# 1471.55
# 1338.59
# 1290.6
# Tractor sales (thousands)
# 53.25
# 58.58
# 98.42
# 82.91
# 79.29
# 82.9
# Domestic air passenger traffic (thousands)
# 124.23
# 121
# 124.87
# 132.14
# 128.88
# 128.9
# Ease of Living
# Consumer Price Index (agricultural labourers)
# NA
# 1215
# 1196
# 1186
# 1180
# 1175
# Consumer Confidence Index
# NA
# 88.1
# NA
# 88.5
# NA
# 87
# Inflation
# CPI inflation, % yly
# 6.80%
# 7.40%
# 4.80%
# 4.30%
# 4.70%
# 5.70%
# WPI inflation; % yly
# -0.52%
# -1.40%
# 4.10%
# 3.50%
# -0.90%
# 1.30%
# Deficit Statistic
# Trade balance $ billion
# NA
# -28.26
# -22.59
# 13.28
# 15.24
# 19.7
# Fiscal deficit (Rs billion)
# NA
# 1542.2
# 2410.8
# 766.9
# 1336
# 2792.7
# GST
# GST collections (Rs billion)
# 1590.69
# 1651.05
# 1614.97
# 1570.9
# 1870.35
# 1601.22
# Sources: RBI, Office of the Economic Advisor; Directorate General of Civvil Aviation (DGCA), CRISIL Research; financial websites_
# Boxes shaded in green denote the best value and red, the worst value
# Best Value
# Worst Value
# None ofthe aforesaid recommendations are based on any assumptions Theseare purely for referenceand theinvestorsare requested to consult their financial advisors before investing:
# Aug
# May
# MARKET
# REVIEW
# C
# India Equity Market Performance
# Institutional flows
# Flls, Dlls and MFs flows
# 15%
# Nifty 50
# 2%
# 15%
# 600
# s&P BSE Sensex
# 2%
# s&P BSE SmallCap
# 32%
# 500
# %f
# 15%
# 400
# s&P BSE FMCG
# 1%
# s&P BSE Bankex
# 2%
# 14%
# 1
# 300
# s&P BSE IT
# 170
# &
# 200
# 2%
# s&P BSE Consumer durables
# 2%
# 7%
# 9
# 100
# 229
# s&P BSE Healthcare
# 2%
# s&P BSE Teck
# 3%
# 13%
# 100
# 36%
# s&P BSE Realty
# 3%
# 2 -200
# s&P BSE Auto
# 3%
# 26%
# 39
# -300
# s&P BSE Oil & Gas
# 30%
# 400
# s&P BSE MidCap
# 4%
# S8P BSECPpEGEgocds
# 6%
# 29%
# 8
# 3
# 1
# 3
# 1
# 2
# 3
# 8]
# 1
# 1 | 8
# 6%
# s&P BSE
# 2%
# 7%
# 44%
# s&P BSE PSU
# 11%
# FII
# Equity Investment
# DII- Equity Investment
# MF Flows
# Equity Investment*
# 20%
# %
# 20%
# 40%
# 1 year returns %
# month returns %
# Source: NSE, BSE, SEBI; NSDL; *data as of September 21,2023
# Indian benchmark equity indices closed higher in Sep-23 as investors showed confidence in domestic growth following upbeat macroeconomic
# data. S&P BSE Sensex and Nifty 50 gained 1.5% and 2% on-month, respectively,in Sept-23. The indices gained by 1.7% and 2.3% respectively on
# quarterly basisin Sep-23
# Domesticmarkets made gains on expectations of faster growth in country's GDP since lastreleased prints
# The markets also reacted positively to positive news on other domestic macroeconomic indicators,
# including strong domestic manufacturing and
# Goods and Services Tax (GST) collection data. Official data released in Sept-23 reflected gross GST revenue collections of Rs 1,590.7 billion in
# Aug- 23 about 11% higherthanthe corresponding month ayearago
# Strong
# cues amid
# hopes ofa ratepausebythe US Federal Reserve (US Fed) andtheECB further added to the gains:
# More
# gains were added on optimism overthe G2O Summit and better-than-expected domestic retail inflation data. India's retail inflation easedto
# 6.83% on-yearin Aug-23 from 7.44% on-yearin July- 23.
# Domestic institutional investors (DIls) continuedto
# equitiesforthe second consecutive month, which also supportedmarket sentiment:
# Dlls boughtequities worth Rs 191.91billionin Sep-23,compared with Rs 250.17 billionin Aug-23
# Eventually,the US Fed's signalling of ratehikesin the future atits policy meet dentedinvestor sentiment:
# More losses were seen after
# foreign portfolio investors (FPIs) snapped their six-month buying streak. Flls sold equities worth Rs 147.68 billion in
# 23,comparedwith buying equities worth Rs 122.62 billionin
# 23.
# Allkey S&P BSE sectoral indices gained during the month, with power; metal and capital goods gaining the most S&P BSE Power, S&P Metal and
# S&P Capital Goods, wereup 7%, 6% and 5%,respectively:
# Source: CRISILResearch: GDP: Gross domestic product; GST: Goods and Services Tax, RBI: Reserve Bank of India; US Fed: US Federal Reserve System
# None of theaforesaid recommendations are based on any assumptions These are purely for reference and the investors are requested to consult their financial advisors before investing:
# 8
# 2
# 39
# Power
# global _
# buy =
# Sep-
# Aug-
# MARKET
# EQUITY
# MARKET
# OUTLOOK
# OUTLOOK
# 3
# Equity Market Outlook
# Globally; major equity markets continued to face pressure from a stronger dollar; rising U.S: Treasury yields; rumours of further rate hikes by the US Fed; slowdown in major European
# economies and rising crude oil prices_
# In the US,the major indices
# s&P 500 and Nasdaq 100
# fell sharply by 4.9% and 5.1% on-month; respectively,in Sep 2023. European equities, indicated by the Stoxx 600 index; declined
# 1.70. Going againstthetide; UK equities movedup 2.3%inthemonth: (Source: FTSE; STOXX;S&P;Nasdaq)
# China's concerning macroeconomic outlook and real estate problems
# been prodding overseas investors to unload Chinese shares The country's equity benchmark
# the Shanghai
# Composite Index - fell 0.3% in Sep 2023.
# Globally, the United Kingdom (+2.3%) , Philippines (+2.4%) and India (+2.0%) witnessed gains. While, Thailand (-6.0%), the US (-4.9%) and South Korea (-3.6%) faced declines: (Source:
# Kotak Research)
# Foreign portfolio investors (FPIs) turned into net sellers after six consecutive months of buying, selling Rs.14,768 crore of domestic equities in Sep-2023. (Source: NSDL)
# Despite net sales by FPIs, the market barometer S&P BSE Sensex and the NSE Nifty5O managed to
# 1.5% and 2.0%, respectively, in Sep 2023.Sector-wise; BSE PSU (+10.6%), BSE
# Power (+7.1%) andBSE Metals (+6.4%) were leading the pack; whereas,BSEFMCG (+1.2%),BSE Bankex (+1.6%) and BSEInfotech (+1.7%) saw lower gains: (Source: BSE and NSE)
# Ourview going forward:
# Post March 2023,equity valuationshave become richer with upbeat sentiments on growth and profitability and downsiderisks pushedtothebackburner:
# India's long-term structural growth story coupled with Govt's push on capital expenditure; healthy tax collection, strong govt. reforms and India as one of the favoured destination
# for China +1themekeepsthe overallmarket sentiments high:
# Earnings from the recently concluded earnings season (Q1FY2023-24) were ahead of expectations, with a bulk of the margin expansion attributable to the softening of commodity
# prices.
# We prefer large-caps given the recent outperformance of mid-cap and small-cap stocks_
# In line with our neutral stance, we prefer schemes that have the flexibility to move between asset classes, like the dynamic asset allocation fund, multi-asset allocation fund or
# diversifiedequity schemes having flexibility to move between market-cap and sectorlthemes:
# We remain watchful ofthese eventsthat could have an influence on equity markets: Run-up to the General election and global central bank actions_
# US
# United States of America; Bps
# basis points; SIP_ Systematic Investment Plan; UK: United Kingdom, FY: Financial Year
# Hence; to summarize; we believe this phase may require investment portfolios to be highly nimble while giving due importance to overall asset allocation: Therefore; we recommend
# adapting below mentioned strategies and investingin these schemes overlong term may be beneficialforyourwealth creationjourney
# Staggered Investments: Continue SIPISTP in Equity Schemes asthe long term structural story of India remains intact
# Asset Allocation: Asthemacrosare changing andto manage volatility, we recommend schemes which can investin various asset classes
# Parking Fund: Asthe valuations are not cheap, hence we recommend some funds to be placed in the Arbitrage or Equity Savings category which can later be deployed post any market
# correction
# SIP: Systematic Investment Plan, STP: Systematic Transfer Plan
# Our Recommendations
# Market is expected to remain volatile due to various macro situations. Hence we recommend schemes with flexibility to invest across
# Asset Classes, Market
# & Sectors/ themes
# Asset Allocation Flexibility
# Flexibility across Sector/ Theme
# Market cap Flexibility
# Recommended Schemes:
# Recommended Schemes:
# Recommended Schemes:
# HYBRID
# ICICI Prudential Business Cycle Fund
# ICICI Prudential Flexicap Fund
# ICICI Prudential Balanced Advantage Fund
# ICICI Prudential Thematic Advantage Fund (FOF)
# ICICI Prudential Focused Equity Fund
# ICICI Prudential Multi-Asset Fund
# ICICI Prudential Value Discovery Fund
# FUND OF FUNDS
# ICICI Prudential Asset Allocator Fund (FOF)
# ICICI Prudential Passive Multi-Asset Fund of Funds
# SIPISTP Strategy:
# Continue SIPISTP as the long term structural story of India remains intact; strongly recommend ICICI Prudential Booster STP#
# Recommended Schemes
# ICICI Prudential Smallcap Fund
# ICICI Prudential India Opportunities Fund
# ICICI Prudential Focused Equity Fund
# ICICI Prudential Large & Mid Cap Fund
# ICICI Prudential Value Discovery Fund
# ICICI Prudential Flexicap Fund
# #ICICI Prudential Booster Systematic Transfer Plan (STP) is a facility where in unitholder (s) can opt to transfer variable amount(s) from designated open ended Scheme(s) of ICICI Prudential Mutual
# Fund to the designated open ended Scheme(s) of ICICI Prudential Mutual Fund: This feature does not in any way give assurance of the performance of any of the Schemes of ICICI Prudential Mutual
# Fund or provide any guarantee ofreturns through Transfer plans Booster STP allows Investors to transferthe amount to Target Scheme basis the EVI calculated and corresponding Trigger Value to the
# same Please readthe terms & conditions intheapplication form before investing or visit WWW iciciprumfcom
# None oftheaforesaid recommendations are based on any assumptions. These are purely forreference and the investors are requested to consulttheir financial advisors before investing:
# 9
# has
# gain
# Cap
# MARKET
# EQUITY
# MARKET
# OUTLOOK
# OUTLOOK
# 3=
# Equity Market Outlook and Valuation Index
# Equity Valuation Index
# 170
# 150
# Book Partial Profits
# 130
# Incremental
# Money to Debt
# 110
# Neutral
# 107.9
# 90
# Invest in Equities
# 70
# Aggressively Invest in Equities
# 50
# }
# }
# 1
# 8
# 8
# J
# ]
# 3
# J
# J
# 3
# 3
# }
# 7
# 3
# 8
# 3
# 8
# 3
# Data as on September 30,2023 has been considered: Equity Valuation Index (EVI) is a proprietary model of ICICI Prudential AMC Ltd: (the AMC) used for
# assessing overall
# equity market valuations The AMC may also use this model for other facilities/features offered by the AMC. Equity Valuation index is calculated by assigning equal weights
# to Price-to-Earnings (PE), Price-to-Book (PB), G-Sec*PE and Market Cap to GDP ratio and any other factor which the AMC may add
# delete from time to time. G-Sec
# Government Securities. GDP
# Gross Domestic Product.
# Return Analysis Table of EVI
# 3
# Return Profile
# 50 TRI
# Particular
# Dark Green (EVI<80)
# Green (80<EVI>100
# Amber (100<EVk120
# Red (120<EVI<130)
# Deep Red (EVI>130)
# Count
# 58
# 98
# 15
# Average
# 25.0%
# 15.9%
# 9.8%
# 8.3%
# 2.8%
# 40.9%
# 35.4%
# 22.6%
# 15.5%
# 7.4%
# Min
# 16.8%
# 4.3%
# -2.2%
# -0.1%
# 0.6%
# <10 % Return
# Count
# 0
# 7
# 51
# 10
# 6
# <10% Return_Percentage Count
# 0.0%
# 12.1%
# 52.6%
# 66.7%
# 100.0%
# Negative Returns
# Count
# 4
# 1
# Negative Returns - Percentage Count
# 0.0%
# 0.0%
# 4.2%
# 6.7%
# 0.0%
# Source: MFI Explorer: Returns are calculated on CAGR basis. Above analysis is done considering the investment period between April 2005 and September 2020. The
# returns are calculated for the period between April 2008 and September 2023.Equity Valuation Index (EVI) is calculated by assigning equal weights to Price-to-Earnings
# (PE) , Price to-Book (PB), G-Sec
# PE and Market Cap to GDP ratio and any other factor which the AMC may add / delete from time to time: G-Sec
# Government Securities.
# GDP
# Gross Domestic Product  Pastperformance may ormaynotsustain infuture
# Steps to readthe above table
# 1.
# 3Yr Monthly Rolling returns of
# 50 TRlis extracted forthe aboveperiod
# 2
# The returns are then classified into differentintervals depending on thebands of EVI (eg,EVI < 80)
# 3.
# Returnsin the interval are selected on basis ofinvestmentperiod fallingin the range of EVI (for Dark Green zone, returns are selected ofinvestmentmade when EVI was less than 80)
# None ofthe aforesaid recommendations are based onany assumptions These are purely forreference and the investors are requested to consulttheir financial advisors before investing:
# 10
# Year
# Nifty
# Max
# Nifty
# MARKET
# REVIEW
# India's Debt Market Performance
# Other Market Indicators
# Debt market indicators
# Rupee fell 0.3% to settle at Rs 83.04 on September 30,2023 compared
# with Rs 82.78 on August 31,2023
# Money market
# 65.00
# Tenure
# CD
# Change
# CP
# Change
# 1M
# 7.05
# 5
# 7.38
# 28
# 3M
# 7.04
# 7.41
# 11
# 70.00
# 6M
# 7.25
# 5
# 7.67
# 7
# 1
# 12M
# 7.45
# 7.80
# 6
# 75.00
# 2
# Bond market
# Tenure
# G-Sec*
# Change
# AAA CB
# Change
# 1
# 80.00
# 1Y
# 7.10
# 8
# 7.53
# 1
# Vulrn
# 3Y
# 7.26
# 10
# 7.63
# 5
# 85.00
# 5Y
# 7.23
# 8
# 7.63
# 5
# J
# 3
# 3
# 8
# 8
# 1
# 1
# 1
# 8
# 3
# 8
# 10Y
# 7.21
# 7.63
# 2
# CP
# commercial paper; CD
# certificate of deposit; CB- corporate bond; * weighted averageyield
# Rupees
# unit of $
# per
# Data sources: RBI, mospinicin, CRISIL fixed income database
# Bank deposits grew 13.6% on-year and 19.8% on year in September vVS
# Corporate bond spreads
# 13.5% on-year and credit; 19.7% in August
# Tenure
# 6M
# 1Y
# 2y
# 3Y
# 5Y
# 7Y
# 10Y
# 22%
# AAA
# 0.37
# 0.5
# 0.3
# 0.24
# 0.27
# 0.25
# 0.3
# 20%
# AA+
# 1.03
# 1.16
# 0.95
# 0.89
# 1.34
# 1.31
# 1.36
# 18%
# AA
# 1.51
# 1.64
# 1.43
# 1.38
# 1.82
# 1.8
# 1.84
# 2
# 16%
# AA-
# 2.51
# 2.64
# 2.44
# 2.38
# 2.82
# 2.8
# 2.84
# A+
# 3.26
# 3.39
# 3.18
# 3.12
# 3.57
# 3.54
# 3.59
# 0
# 14%
# 12%
# A
# 4.56
# 4.69
# 4.48
# 4.42
# 4.87
# 4.84
# 4.89
# ;
# 10%
# A-
# 4.8
# 4.93
# 4.72
# 4.66
# 5.11
# 5.08
# 5.13
# 8%
# G-sec and corporatebonds data ason August31
# Weighted average yields for G-sec data
# 6%
# 6 month G-sec: 182-day T-bill rate; 1-year G-Sec: 6.69% GS 2024; 3-year G-sec: 5.63% GS
# 4%
# 2026;5-yearG-sec: 07.17
# 2028;10-year G-sec: 7.26% GS 2033
# 3
# 8
# 3
# 1
# 3
# 1
# 2
# 3
# 3
# 3
# 1
# 3
# 8
# Liquidity in the banking system
# Deposits growth
# Credit growth
# 4000
# Brent crude price rose 9.77% to close at $95.31 per barrels on
# 2000
# 1
# September 29 as against $86.8 per barrels @ month ago
# 4
# ~2000
# ~nMlvl
# 120
# 4000
# 1
# 110
# 6000
# [
# 8000
# 1
# 90
# 10000
# 2
# 80
# 12000
# 8
# #
# 70
# 1
# 1
# 4
# ;
# 8
# 8
# ;
# 60
# 6
# 50
# Source: RBI
# 40
# Average of interbank call money rates remained below the RBI's repo rate of 6.50% in
# 23
# 30
# owing to surplus liquidity in the system:
# 20
# Notably; the Indian banking system witnessed deficit in liquidity later in the month following the
# RBI's direction to banks to set aside 10% of their incremental deposits as incremental cash reserve
# 8
# 3
# 8
# 3
# 8
# 1
# 8
# 1
# 8
# 1
# 8
# ratio (I-CRR). However;the RBl eventually decided to discontinue thel-CRR by releasing 25% ofthe
# I-CRR maintained on September 9, 2023, another 25% on September 23,2023 and balance 50%
# Oil Price ($ per barrel)
# on October 7,2023.
# Outflows related to advance tax payments and preparations for GST collection also caused deficit
# in
# 1liquidity during September:
# Gold price in India closed at Rs 57719 per 10 grams on September 29
# Government bond yields ended higher in Sep-23. The yield on the 10-year benchmark 7.18% 2033
# bondclosed at 7.22%on September 29,2023 compared with 7.13% on August31,2023.
# 2023 down 3% from Rs 59485 per 10 grams on August 31
# Yields rose
# mirroring
# in US treasury yields, after the August US non-farm payrolls report
# reflected thattheeconomy added morejobs than expected lastmonth Rising expectationsthatthe
# 65000
# US Fedmay keep rateshigherfor longer also keptbond prices under pressure.
# Rising global oil prices and higher bond supply witnessed in the weekly debt auction also
# 8
# supported yields:
# 55000
# Bond prices declined further as the government keptits borrowing target for the second half of the
# 9
# fiscal unchanged.
# g
# The finance ministry said that the government would stick to its market borrowing plan of Rs 6.55
# 45000
# lakh crore in the second half (October-March) of this fiscal: It also decided to introduce a 50-year
# 8
# bond forthefirsttimeto cater to demand forlonger-duration securities:
# Further gains in yields were
# short following reports of RBI seeking views from private and
# 8
# 35000
# foreign banks for settling bond trades on the Euroclear platform_
# Bond prices rose further dueto concerns over
# inflation and after the RBI revised guidelines on
# 1
# the categorisation of bankinvestment:
# 25000
# Yields also declined after JPMorgan announced that India would be a part of its influential GBI-EM
# 0
# incersvhtestaietiag Oeeshazowed
# any impact from FTSE Russell not including India in its debt
# 8
# 3
# 8
# 1
# 8
# 1
# 8
# 3
# 8
# 3
# 3
# index
# FTSE Russell kept India
# on
# watch list for inclusion in the FTSE Emerging Markets
# Indian Gold prices per 10 grams
# Government Bond Index
# Source: CRISIL Research, RBI: Reserve Bank of India (RBI), US Fed: US Federal Reserve System; US:
# Source: RBI, IBJA, Crisil Research
# United States
# None ofthe aforesaid recommendations are based onany assumptions. These are purely forreference and the investors are requested to consult their financial advisors before investing:
# 11
# GS
# Mnxv
# Ww
# 100
# 2
# Sep-
# gains
# cut
# rising
# MARKET
# Fixed
# Income
# OUTLOOK
# Outlook
# O
# Fixed Income Outlook
# On Inflation, overall price growth cooled down slightly due to easing vegetable prices  But;a stronger dollar coupled with rising oil prices signalupward pressure on inflation growth in the
# nearfuture:
# We believe that over the medium-term, monetary policy works in conjunction with the business cycle
# assessment suggests that the economy is growing at a reasonable pace and
# inflation is at a moderate but tolerable level. Effectively, this phase is a neutral zone for the RBl as the economy can thrive without strict policy measures Hence; we believe the RBI to
# maintain pause on ratehikes in the upcoming policy meet: However; we do expectthetone ofmonetary policy to be slightly hawkish given the evolving global cues
# Inthe current environment of stable macros and elevated interest rates, we recommend accrual approach: We recommend
# limiting the duration up to 3 years Dynamic duration scheme
# is also suitable asit actively managesthe duration andtherisk-rating allocation depending upon the situation. Floating rate bonds,too,are a decent choice dueto theiraccruals_
# We believe the appeal of fixed income as an asset class has increased significantly: This can be attributed to the higher yields provided by the environment's high inflation and rising
# interest rates: The benefit of debt schemes
# ease of liquidity, diversification, professional management and a hassle free investing experience
# makes it a better investment option
# comparedto otherfixed income products
# Market Activity
# The benchmark 10-year G-Sec yield was up 5 bps on-month to 7.22% on Sep 30,2023. Liquidity conditions remained tight despite discontinuance of Incremental-Cash Reserve Ratio
# requirement; likely due to advance tax, GST payments and possible sale of dollars by the RBI: The 91-day T-bill yield rose 7 bps in a month to 6.86% while the 182-day T-bill yield rose 8
# bpsto 7.08%. (Source: CCIL; RBI)
# Corporate bond yields rose in tandem; with the longer-end of the curve rising faster than the shorter-end. Credit spreads were impacted on the shorter-end of the yield curve: (Source:
# NSE)
# G-Sec-Central Government Securities; bps
# basis points; T-bill_ Treasury Bill; CPI-Consumer Price Inflation:
# ICICI Prudential Debt Valuation Index for Duration Risk Management
# 10
# 9
# Highly Aggressive
# 8
# 7
# Aggressive
# 6
# Moderdte
# ;
# Cautious
# 2.69
# 2
# 1
# Very Cautious
# 0
# 8
# 3
# 3
# 3
# 3
# 3
# 8
# 8
# 8
# 8
# 8
# 8
# :
# 8
# 8
# 8
# In the current business cycle; wherein growth continues to remain strong and inflation moves broadly within the RBI's tolerable range; no monetary policy
# action is warranted: Due to which;
# higher duration may not result in additional returns Hence; we maintain our cautious stance: However; if the
# yields move higher the modelmay suggestmoving to moderate duration:
# Data as on September 30, 2023. Debt Valuation Index considers WPI, CPI, Sensex returns, Gold returns and Real estate returns over G-Sec   yield; Current
# Account Balance, Fiscal Balance; Credit Growth and Crude Oil Movement and any other factor which the AMC may add / delete from time to time for calculation
# Debt Valuations Index is a proprietary model of ICICI Prudential AMC Ltd (the AMC) used for assessing overall debt valuations The AMC may also use this model
# for otherfacilities /features offered by the AMC. RBI
# Reserve Bankof India_
# Our Recommendation
# Approach
# Scheme Name
# Call to Action
# Rationale
# Arbitrage
# ICICI Prudential Equity - Arbitrage Fund
# Invest with 3 Months &abovehorizon
# Spreads atreasonablelevels
# Measured Equity
# ICICI Prudential Equity Savings Fund
# Invest with 6 Months &abovehorizon
# Potential for upside and limiting
# downside
# Short Duration
# ICICI Prudential Savings Fund
# Investfor parking surplus funds
# Accrual + Moderate Volatility
# ICICI Prudential Ultra Short Term Fund
# ICICI Prudential Floating Interest
# Fund
# Accrual Schemes
# ICICI Prudential Credit Risk Fund
# Core Portfolio with >1 Yrinvestmenthorizon
# Better Accrual
# ICICI Prudential Medium Term Bond Fund
# Dynamic Duration
# ICICI Prudential All Seasons Bond Fund
# Long Term Approach with >3 Yrs investmenthorizon
# Active Duration and Better Accrual
# None ofthe aforesaid recommendations are based on any assumptions These are purely for reference andthe investors are requestedto consult their financial advisors before investing:
# 12
# Our
# 8
# 8
# 8
# 8
# taking
# ICICI Prudential Bluechip Fund
# (
# Since
# 2008
# Category
# (An open ended equity scheme predominantly investing in large cap stocks-)
# Large
# Fund
# MPLe
# Returns of ICICI Prudential Bluechip Fund
# Growth Option as on September 30, 2023
# Style Box
# Particulars
# 1 Year
# 3 Years
# 5 Years
# Since inception
# CAGR
# Current
# CAGR
# Current
# CAGR
# Current
# CAGR
# Current
# (%)
# Value of
# (%)
# Value of
# (%)
# Value of
# (%)
# Value of
# Investment
# Investment
# Investment
# Investment
# Style
# of Rs: 10000
# 'of Rs: 100O0
# of Rs: 10000
# of Rs- 100O0
# Value
# Blend
# Growth
# Scheme
# 21.12
# 12105.99
# 24.78
# 19414.65
# 14.35
# 19568.01
# 14.43
# 79270.00
# Size
# Large
# Nifty 100 TRI (Benchmark)
# 13.37
# 11333.53
# 21.20
# 17793.80
# 13.23
# 18628.06
# 11.04
# 49975.75
# Nifty 50 TRI (Additional Benchmark)
# 16.11
# 11606.17
# 21.89
# 18099.06
# 13.75
# 19060.22
# 10.72
# 47810.31
# Mid
# NAV (Rs:) Per Unit (as on September 29,2023
# 79.27)
# 65.48
# 40.83
# 40.51
# 10.00
# Notes:
# Small
# Different plans shallhave different expense structure: The performance details provided herein are of ICICI Prudential Bluechip Fund:
# The scheme is currently managed by Anish Tawakley and Vaibhav Dusad
# Mr: Anish Tawakley has been managing this fund since Sep 2018. Total Schemes managed by the Fund Manager is 5 (4 are jointly
# managed).
# Mr: Vaibhav Dusadhas been managing this fund since Jan 2021. Total Schemes managed by the Fund Manageris 3 (2 arejointly managed) Refer annexure from page no. 107 for performance of other schemes
# Diversified
# currently managed by Anish Tawakley and Vaibhav Dusad:
# Date of inception:23-May-08.
# Past performance may or maynot be sustainedin future and the same may not necessarily provide the basis for comparison with other investment
# Load isnot considered forcomputation of returns_
# 6. In case
# the startlend date ofthe concerned period is
# nonbusiness date (NBD), the NAV ofthe previous date is considered
# computation of returns
# NAV per unit shown inthe tableisas on the start date of
# the said period
# The performance ofthe scheme is benchmarked to the Total Return variantofthe Index The benchmark ofthe schemehas been revised from Nifty 50 TRIto Nifty 100 TRI w.e.f:May 28,2018
# Mr. Rajat Chandak has ceasedto bea fundmanagerofthis scheme with effect from March 1,2022
# Scheme Details
# Fund Managers**
# Inception/Allotment date: 23-May-08
# Exit load for Redemption
# Switch out :
# Anish Tawakley (Managing this fund since Sep, 2018
# Lumpsum & SIP / STP / SWP Option
# & Overall 28 years of experience)
# Upto 1 Year from allotment
# 1% of applicable NAV,
# more than 1 Year
# Nil
# Monthly AAUM as on 30-Sep-23
# Rs. 41,622.10 crores
# Mr: Vaibhav Dusad (Managing this fund since Jan;
# Closing AUM as on 30-Sep-23
# Rs. 41,833.39 crores
# 2021 & Overall 12 years of experience)
# Application Amount for fresh Subscription
# Rs.1OO (plus in multiples of Re.1)
# Total Expense Ratio
# No. of folios
# Min AddlInvestment
# Other
# 1.58% p. a.
# in the Scheme
# Indicative Investment Horizon: 5 years & above
# Direct
# 1.01% p. a.
# 18,11,433
# Rs.1OO (plus in multiples of Re.1)
# NAV (As on 29-
# 23): Growth Option
# 79.27
# IDCW Option
# 27.51
# Direct Plan Growth Option
# 86.16
# Direct Plan IDCW Option
# 49.68
# Portfolio as on September 30,2023
# Quantitative Indicators
# Companyllssuer
# Rating
# % to
# % to NAV
# Companyllssuer
# Rating
# % to
# % to NAV
# Average Dividend Yield
# NAV
# Derivatives
# NAV
# Derivatives
# 1.19
# Equity Shares
# 88.43%
# 2.60%
# Pharmaceuticals &
# Biotechnology
# 2.94%
# Auto Components
# 0.88%
# Sun Pharmaceutical Industries Ltd.
# 1.53%
# Annual Portfolio Turnover Ratio
# Motherson Sumi Systems Ltd_
# 0.88%
# Lupin Ltd:
# 1.41%
# Automobiles
# 7.77% -0.30%
# Power
# 1.76%
# Equity
# 0.24 times
# Maruti Suzuki India Ltd.
# 3.67%
# NTPC Ltd.
# 1.76%
# Hero Motocorp Ltd.
# 1.56%
# Realty
# 1.05%
# Std Dev
# TVS Motor Company Ltd.
# 1.39% -0.30%
# DLF Ltd.
# 1.05%
# (Annualised)
# Sharpe Ratio
# Portfolio Beta
# Tata Motors Ltd.
# DVR
# 1.15%
# Retailing
# 0.90%
# 13.01%
# 1.24
# 0.88
# Banks
# 20.01% -0.69%
# Avenue Supermarts Ltd.
# (D-Mart)
# 0.90%
# ICICI Bank Ltd.
# 9.16%
# Telecom
# Services
# 3.76%
# The figures are not netted for derivative transactions
# Risk
# rate basedon thelast Overnight MIBOR cut-off of 6.959
# HDFC Bank Ltd:
# 5.22%  -0.69%
# Bharti Airtel Ltd.
# 3.76%
# #*In addition to the fund manager managing this fund, overseas investment is managed by Ms.
# Axis Bank Ltd.
# 4.94%
# Foreign Equity
# 0.74%
# Sharmila D'mello
# State Bank Of India
# 0.68%
# Index Futures/Options
# 4.15%
# @@TotalExpense Ratio
# as on thelastday of themonth:
# The Global Industry Classification Standard ("GICS")
# was developed by and is the exclusive
# Beverages
# 0.98%
# Nifty 50 Index
# Futures
# 4.15%
# property and
# service mark of MSCI Inc: ("MSCI") and Standard
# Poor's Financial Services LLC
# United Breweries Ltd.
# 0.98%
# Treasury Bills
# 0.61%
# ("S&P") andis licensed for use
# by ICICI Prudential
# sset Management Company Ltd. Neither MSCI;
# S&P nor any other party involved in making or compiling the GICS or any GICS classifications
# Capital Markets
# 0.84%
# 182 Days Treasury Bill 2023
# SOV
# 0.58%
# makes any express
# implied warranties
# representations with respect to such standard
# HDFC Asset Management Company Ltd:
# 0.84%
# 91
# Treasury Bill 2023
# SOV
# 0.02%
# classification (or the results to be obtained by the use thereof)
# and all such parties hereby
# expressly disclaim all warranties of originality, accuracy, completeness
# merchantability and
# Cement & Cement Products
# 4.47%
# Equity less than 1% of corpus
# 9.34%
# fitness for
# particular purpose with respect to any of such standard or classification. Without
# Ultratech Cement Ltd.
# 3.78%
# Short Term Debt and net
# any of the foregoing;in no event shall MSCI S&P,any of their affiliates or any third party
# involved in
# making or compiling the GICS or any GICS classifications have any liability for any
# Grasim Industries Ltd_
# 0.69%
# current assets
# 8.36%
# direct, indirect, special, punitive, consequential or any other damages (including lost profits) evenif
# Construction
# 7.91% -0.57%
# Total Net Assets
# 100.00%
# notified ofthe possibility of such damages:
# Refer page no 99 to 106 for details on option, entry load_
# SWP , STPIFlex STP
# minimum
# Larsen & Toubro Ltd:
# 7.91% -0.57%
# redemption amount pertaining to the scheme
# Consumable Fuels
# 1.03%
# Top Ten Holdings
# For IDCW History
# Refer page no: from 125t0 130, For SIP Returns
# Refer page no. from 119to
# Securities and the
# corresponding derivative exposure with less than 1%
# 122,For Investment Objective: Refer pageno.from 131t0 133
# Coal India Ltd.
# 1.03%
# to NAV, have been clubbed together with
# consolidated limit of 10%
# Diversified Fmcg
# 1.99%
# Derivatives are considered at exposure value:
# ITC Ltd.
# 1.99%
# Riskometer
# Insurance
# 2.67%
# SBI Life Insurance Company Ltd.
# 1.38%
# Ihis product_labellingis_gpplicable only_tothe scheme
# ICICI Prudential Life Insurance
# This Product is suitable for investors who are seeking*
# Company Ltd.
# 1.28%
# 5 Stock Holdings
# Long Term Wealth Creation
# An open ended equity scheme predominantly investing in large cap stocks_
# It
# Software
# 8.97%
# Infosys Ltd.
# 5.70%
# ICICI Bank Ltd:
# 9.16%
# Scheme
# Benchmark
# Tech Mahindra Ltd.
# 1.69%
# Larsen & Toubro Ltd:
# 7.91%
# (Nifty_10Q_TRI)
# HCL Technologies Ltd:
# 1.57%
# Reliance Industries Ltd.
# 6.56%
# Non
# Ferrous Metals
# 1.08%
# Infosys Ltd.
# 5.70%
# High
# Herotel
# Hindalco Industries Ltd.
# 1.08%
# HDFC Bank Ltd
# 5.22%
# "gh
# Ko,
# Oil
# 1.34%
# Oil & Natural Gas Corporation Ltd:
# 1.34%
# 5 Sector
# Holdings
# 33
# 3
# 33
# Personal Products
# 1.11%
# Financial Services
# 26.09%
# Procter & Gamble Hygiene and Health
# Oil, Gas & Consumable Fuels
# 10.25%
# Investors understand that their principal
# Benchmark riskometer is at
# Care Ltd:
# 1.11%
# Information Technology
# 9.85%
# will be at
# High risk
# High risk
# Petroleum Products
# 7.62%
# Automobile And Auto Components
# 9.47%
# #Investors should consult their financial advisers if in doubt about whether the
# Reliance Industries Ltd:
# 6.56%
# Construction
# 7.91%
# product is suitable for them:
# Bharat Petroleum Corporation Ltd:
# 1.06%
# 13
# AEARS
# Cap
# Ifor C
# The
# Sep--
# free
# Days
# limiting
# Top
# Moderatel
# Moderc
# Moderate ,
# (Moderdte /
# ~Lowto
# Low to
# 1
# ~Moderate
# Top
# Very
# Very
# ICICI Prudential Flexicap Fund
# Category
# (An open ended dynamic equity scheme investing across large cap; mid cap & small cap stocks)
# Flexi
# Returns of ICICI Prudential Flexicap Fund
# Growth Option as on September 30, 2023
# Style Box
# Particulars
# 1 Year
# 3 Years
# 5 Years
# Since inception
# CAGR
# Current
# CAGR
# Current
# CAGR
# Current
# CAGR
# Current
# ...
# performance: When a mutual fund has
# a
# high standard deviation, its means its
# Benchmark :
# range of performance is wide, implying greater volatility:
# A group of securities, usually
# a market index whose performance is used as
# standard or benchmark to
# measure investment performance of mutual funds,
# Sharpe Ratio
# among other investments: Some typical benchmarks include the
# Sensex,
# BSEZOO,BSESOO, 10-Year Gsec:
# The Sharpe Ratio, named after its founder; the Nobel Laureate William Sharpe; is a
# measure of risk-adjusted returns It is calculated using standard deviation and
# excess return to determine reward per unit ofrisk:
# Entry Load:
# A mutual fund may have a sales
# charge or load at the time of
# andlor exit to
# Beta Ratio (Portfolio Beta)
# compensate the distributorlagent: Entry load is charged at the time an investor
# purchases the units of a mutual fund: The entry load is added to the prevailing NAV
# Beta is a measure of an investment's volatility vis-a-vis the market Beta of less
# atthe time of investment For instance; ifthe NAV is Rs. 100 and the entry load is 1
# than
# 1
# means that the security will be less volatile than the market:
# A beta of
# %,the investor will enterthefundatRs. 101
# greaterthan 1 impliesthatthe security's
# will be more volatile thanthemarket_
# Note: SEBI has abolished entry load and mandated that the upfront commission to
# Average portfolio PE (Average PIE) :
# distributors will be paid by the investor directly to the distributor;
# based on his
# It is price to earnings ratio of the stocks calculated for the entire portfolio on
# assessment of variousfactors including the service rendered by the distributor:
# weighted average basis:
# Fund Manager:
# Average portfolio price to book ratio (Average PIBV)
# An employee of the asset management company such as a mutual fund or life
# Itis price to book value ofthe stocks calculated forthe entire portfolio on a
# weighted
# insurer, who
# manages investments of the scheme. He is usually part of a larger
# average basis.
# team offundmanagers andresearch analysts_
# Average portfolio dividend yield (Average Dividend Yield)
# Application AmountforFresh Subscription:
# It is dividend yield of the stocks calculated for the entire portfolio on
# weighted
# Thisisthe minimum investment amountfora new investorin a mutual fund scheme_
# average basis.
# Minimum Additional Amount:
# Net Equity =
# This is the minimum investment amount for an existing investor in a mutual fund
# Net equity level is the net equity exposure percentage adjusted for any derivative
# scheme_
# positions in stocks orindex forhedgingorrebalancing purpose
# Yield to Maturity
# R Squared:
# The Yield to Maturity or the YTM is the rate of return anticipated on
# a bond if held
# Itis a statistical measure of how closely the portfolio returns are correlated with its
# until maturity. YTM is expressed as an annual rate: The YTM factors in the bond's
# benchmark
# current market price, parvalue, coupon interestrate andtimeto maturity:
# AUM
# SIP :
# AUMor assets under managementrefers to the recent /updated cumulative market
# SIP
# or systematic investment plan
# works on the principle of making periodic
# value of investments managed by a mutualfundoranyinvestmentfirm:
# investments of
# fixed
# sum. It
# works similar to
# recurring bank deposit:
# For
# instance, an investor may optfor an SIP thatinvests Rs 500 every 15th ofthe month
# Holdings
# inan equity fundfor a period of threeyears.
# The holdings orthe portfoliois a mutual fund's latestorupdated reported statement
# of investments/securities. These are usually displayed in terms of percentage to net
# NAV:
# assets orthe rupee value or both The objective is to give investors an idea of where
# The NAV or the net asset value is the total asset value per unit of the mutual fund
# their moneyis being invested bythe fund manager:
# after deducting all related and permissible expenses: The NAV is calculated at the
# end of
# business
# It is the value at which the investor enters or exits the
# mutualfund_
# 135
# Nifty,
# entry
# entry
# every
# Nifty,
# entry
# price
# day:
# every
# Schedule 2: How To Read Factsheet
# Nature of Scheme:
# Freedom SIP :
# The investment objective and underlying investments determine the nature of the
# ICICI Prudential Freedom SIP (the Facility) including the default monthly SWP
# mutual fund scheme: For instance; a mutual fund that aims at generating capital
# payouts do not guarantee; assure; promise or indicate fixed returnslperformance of
# appreciation by investing in
# stock markets is an equity fund
# or
# growth fund:
# any schemes of ICICI Prudential Mutual Fund or under SIP or of the withdrawal
# Likewise,
# mutual fund that aims at capital preservation by investing in debt
# markets is a debt fund or income fund: Each of these categories may have sub-
# underthe Facility:
# categories:
# The Facility is an optional feature that allows initial monthly investments through
# Rating Profile
# SIP in the source scheme, switch to target scheme after a pre-defined tenure and
# Mutual funds
# invest in
# securities
# after   evaluating
# their   creditworthiness
# as
# then monthly SWP from the target scheme The SWP will be processed either till
# disclosed by the ratings
# A
# depiction of the mutual fund in various investments
# Dec 2099 ortillthe units are available in the target scheme, whicheveris earlier: The
# based on their ratings becomes the rating profile of the fund: Typically, this is
# default monthly SWP payout amounts indicates the
# amount that can be
# feature of debtfunds_
# withdrawn:
# Flex STP :
# Please read the terms and conditions in the application form before investing orvisit
# ICICI Prudential Transfer Plan ("Flex STP") is a facility wherein unit holder(s) of
# HYPERLINK "http Jlwww iciciprumf com"' wWW iciciprumfcom
# designated open-ended Schemels) of ICICI Prudential Mutual Fund can opt to
# transfer variable amount(s) linked to value of investments under Flex STP on the
# date
# of   transfer
# at
# pre-determined
# intervals   from
# designated
# open
# ended
# #Note
# IDCW = Income Distribution cum capital withdrawal option:
# Scheme(s) of ICICI Prudential Mutual Fund [hereinafter referred to as "Transferor
# IDCW Payout
# Payout of Income Distribution cum capital withdrawal
# Scheme"] to the growth option of designated open-ended Scheme(s) of ICICI
# option:
# Prudential Mutual Fund [hereinafter referred to as "Transferee Scheme"].
# IDCW Reinvestment
# Reinvestment of Income Distribution cum capital
# withdrawaloption_
# Booster STP :
# IDCW Transfer
# Transferof Income Distribution cum capital withdrawal
# ICICI Prudential Booster Systematic Transfer Plan ("Booster STP") is
# facility
# Plan:
# wherein unit holder(s) can optto transfer variable amount(s) from designated open
# ended Schemels) of the Fund [hereinafter referred to as
# 'Source Scheme"] to the
# Investors are requested to note that nomenclature of 'Dividend' and has been
# designated open-ended Scheme(s) of the Fund [hereinafter referred to as "Target
# changedto 'IDCW' pursuantto SEBI circular:
# Scheme"] at defined intervals. The Unitholder would be required to provide a Base
# Installment Amount that is intended to be transferred to the Target Scheme:
# The
# Booster SIP:
# variable amount(s) or actual amount(s) of transfer to the Target Scheme will be
# ICICI Prudential Booster Systematic Investment Plan ("Booster SIP") is a facility
# linked to the Equity Valuation Index (hereinafter referred to as EVI): The EVI is
# wherein unit holder(s) can opt to invest a pre-determined sum at defined intervals
# derived by assigning equal weights to Price to Earnings (PE), Price to book (PB); (G-
# to a designated open ended Scheme(s) of ICICI Prudential Mutual Fund [hereinafter
# SecxPE) and Market Cap to Gross Domestic Product (GDP) or such other factors as
# referred to
# as "Source
# Scheme"] and then the
# amount is transferred
# to the
# may be determined by the AMC from time to time: For list of source and target
# designated open-ended Scheme(s) of ICICI Prudential Mutual Fund [hereinafter
# referred to as
# Target Scheme"] at defined intervals. The Unit holder would be
# schemes investors are requestedto referto
# application form:
# required to provide a SIP amount which will be considered as the Base Installment
# Amountthatisintended to be transferred to the Target Scheme: The actual amount
# Source Schemes: ICICI Prudential All Seasons Bond Fund, ICICI Prudential Banking
# of transfer to the Target Scheme will be linked to the Equity Valuation Index
# & PSU Debt Fund, ICICI Prudential Bond Fund, ICICI Prudential Constant Maturity
# (hereinafter referred to as EVI) which is
# proprietary model of ICICI Prudential
# Gilt Fund, ICICI Prudential Corporate Bond Fund, ICICI Prudential Credit Risk Fund,
# Asset Management Company Limited (the AMC): The EVI is derived by assigning
# ICICI Prudential Floating Interest Fund, ICICI Prudential Gilt Fund, ICICI Prudential
# equal weights to Price to Earnings (PE), Price to book (PB) , (G-Secx PE) and Market
# Liquid Fund, ICICI Prudential Long Term Bond Fund, ICICI Prudential Medium Term
# Cap to Gross Domestic Product (GDP) or such other factors as may be determined
# Bond Fund, ICICI Prudential Money Market Fund, ICICI Prudential Overnight Fund,
# bythe AMC from time to time
# ICICI Prudential Savings Fund, ICICI Prudential Short Term Fund, ICICI Prudential
# Ultra Short Term Fund, ICICI Prudential Equity
# Arbitrage Fund, ICICI Prudential
# Equity Savings Fund; ICICI Prudential Regular Savings Fund, ICICI Prudential Debt
# Management Fund (FOF)
# Target Schemes: ICICI Prudential Balanced Advantage Fund, ICICI Prudential
# Equity & Debt Fund, ICICI Prudential Multi-Asset Fund; ICICI Prudential
# Asset
# Allocator Fund (FOF) , ICICI Prudential Banking and Financial Services Fund, ICICI
# Prudential
# Bharat  Consumption
# Fund,
# ICICI
# Prudential
# Bluechip
# Fund,
# ICICI
# Prudential
# Business
# Cycle
# Fund,
# ICICI
# Prudential
# Commodities
# Fund,
# ICICI
# Prudential Dividend Yield Equity Fund, ICICI Prudential ESG Fund, ICICI Prudential
# Exports and Services Fund, ICICI Prudential FMCG, ICICI Prudential Focused Equity
# Fund, ICICI Prudential India Opportunities Fund, ICICI Prudential Infrastructure
# Fund; ICICI Prudential Large & Mid Cap Fund, ICICI Prudential
# Term Equity
# Fund (Tax Saving), ICICI Prudential Manufacturing Fund, ICICI Prudential MidCap
# Fund, ICICI Prudential MNC Fund, ICICI Prudential Multicap Fund, ICICI Prudential
# Pharma Healthcare and Diagnostics (PH.D:) Fund, ICICI Prudential Quant Fund,
# ICICI Prudential Smallcap Fund; ICICI Prudential Technology Fund; ICICI Prudential
# Value Discovery Fund, ICICI Prudential Thematic Advantage Fund (FOF), ICICI
# Prudential Passive Strategy Fund (FOF) , ICICI Prudential India Equity Fund (FOF) ,
# ICICI Prudential BHARAT 22 FOF, ICICI Prudential Nifty 100 Low Volatility 30 ETF
# FOF,ICICI Prudential Nifty 50 Index Fund, ICICI Prudential Nifty Next 50 Index Fund,
# ICICI Prudential S&P BSE Sensex Index Fund, ICICI Prudential Transportation and
# Logistics Fund, ICICI Prudential Innovation Fund:
# Freedom SWP :
# ICICI Prudential Freedom SWP enables investors to withdraw the investment
# corpus in systematic and timely manner: Investors can choose the
# Up % for
# withdrawals to meet their recurring andfuture expenses:
# 136
# likely
# Long
# Top
# ICICI Prudential Mutual Fund Corporate Office
# ONE BKC, A - Wing; 13th Floor; Bandra-Kurla Complex; Mumbai 400 051, India:
# Tel: 022
# 26525000 Fax: 022
# 26528100, website: www icicipruamccom; email id: enquiry@icicipruamccom
# Statutory Details & Risk Factors
# Please note that the Risk-o-meter(s) specified above will be evaluated and updated on a monthly basis. Please refer to httpsIwww icicipruamc comlnews_
# and-updateslalLnews for more details
# YTM
# Yield to maturity should not be construed as minimum return offered by Scheme:
# Yield to Maturity for Schemes holding Additional Tier
# 1 Bonds and Tier 2 Bonds issued by Banks is computed based on Yield used for valuation for such
# Securities_
# Annualized Yield to Maturity converts instrument coupon into annualized format wherein the coupons are paid on
# a semi-annualized basis
# As per AMFI Best Practices Guidelines Circular No. AMFI 35P/ MEM-CORI 72
# 2022-23 dated December 31, 2022 on Standard format for disclosure
# Portfolio YTM for Debt Schemes, Yield of the instrument is disclosed on annualized basis as provided by Valuation agencies:
# Current assets shall be read as Net current assets
# Mutual Fund investments are subject to marketrisks,read all scheme related documents carefully:
# AII
# figures and other data given in this document are dated as of September 30,2023 unless stated otherwise The same may or may not be relevant at a future
# date: The information shallnotbealtered in any way,transmitted to, copied ordistributed,in partorin whole; to anyotherperson ortothe media or reproducedin
# any form, without prior written consent of ICICI Prudential Asset Management Company Limited (the AMC) Prospective investors are advised to consult their
# ownlegal, tax and financial advisors to determine possible tax; legal and other financialimplication or consequence of subscribing to the units of ICICI Prudential
# Mutual Fund_
# Disclaimer: In the preparation of the material contained in this document; the AMC has used information that is publicly available,
# including
# information
# developed in-house Some ofthe material(s) used in the documentmay have been obtained from members/persons other than the AMC andlor its affiliates and
# which may have been made available to the AMC andlor to its affiliates. Information gathered and material used in this document is believed to be from reliable
# sources. The AMC however does not warranttheaccuracy, reasonablenessand
# or
# 'completeness of any information. Wehave included statements / opinions
# recommendations in this document; which contain words, or phrases such as
# will" , "expect" ,
# "should"_
# 'believe" and similar expressions or variations of such
# expressions, that are "forward looking statements
# Actual results may differ materially from those suggested by the forward looking statements due to risk or
# uncertainties associated with our expectations with respect to,butnotlimitedto, exposureto marketrisks, general economic and political conditions in India and
# other countries
# globally, which have
# an impact on
# our services and / or investments, the monetary and interest policies of India, inflation, deflation,
# unanticipated turbulence in interest rates, foreign exchange rates, equity prices or other rates or prices etc ICICI Prudential Asset Management Company
# Limited (including its affiliates), the Mutual Fund; The Trust and any of its officers, directors, personnel and
# employees, shall not liable for any loss, damage of
# anynature;
# including butnotlimited to direct; indirect; punitive; special, exemplary, consequential, as also any loss ofprofitin any way arising from theuseofthis
# material in any
# manner. Further, the information contained herein should
# not be construed
# as forecast or promise
# The recipient alone shall be fully
# responsiblelareliablefor any decision taken on this material:
# 137
# 0ICICI
# PRUYENTIAL
# MUTUAL
# FUND
# A choice of
# opportunities
# across asset classes:
# Equity
# Debt
# Gold ETFI
# ETCD
# Invest in
# ICICI Prudential
# Multi-Asset Fund
# *The scheme will take exposure to Units of Gold ETFs
# Exchange Traded Commodity Derivatives.
# To invest, contact your Mutual Fund Distributor
# IPRUTOUCH
# wwwiciciprumfcom
# 3
# ICICI Prudential Multi-Asset Fund (An open ended scheme investing in Equity, Debt and Exchange
# Traded Commodity Derivativeslunits of Gold ETFslunits of REITs & InvlTs/Preference shares ) is
# suitable for investors who are seeking
# x9
# High
# Investors
# Long term wealth creation
# understand that
# An open ended scheme investing across asset classes
# their principal
# 3
# 2g
# will be at Very
# #Investors should consult their financial advisers if in doubt about whether the product is suitable for them_
# High risk
# The Risk-o-meter specified above will be evaluated and updated on a monthly basis_
# Please refer https: Ilwww icicipruamc com/news-and-updateslall-news for more details on scheme riskometers_
# Mutual Fund investments are subject to market risks, read all scheme related documents carefully:
# App
# RISKOMETER
# SCHEME
# Moderately
# Moderate/
# 1
# 3
# 3

# %% [markdown]
# AS we observe, the OCR alone is not able to extract the text in desired format. Hence we should utilize multimodal tools that can recognize the various entities like descriptions, tables etc. and extract them separately. Table transformer, flamingo etc can be taken to use

# %%
#Chunking fund data

def chunkByFundDetails(data):
    chunks = {}
    for row in data:
        fund_name = row['Fund Name']
        if fund_name not in chunks:
            chunks[fund_name] = []
        chunks[fund_name].append(row)
    return chunks

def chunkByFundPerformance(data):
    performance_data = []
    fund_manager_data = []
    for row in data:
        performance_chunk = {
            'Fund Name': row['Fund Name'],
            'Performance Data': {
                'Date': row['Date'],
                'Returns': row['Returns']
            }
        }
        fund_manager_chunk = {
            'Fund Name': row['Fund Name'],
            'Fund Manager': row['Fund Manager']
        }
        performance_data.append(performance_chunk)
        fund_manager_data.append(fund_manager_chunk)
    return performance_data, fund_manager_data

# %%
#Query Analysis using topic modelling

import nltk
from nltk.tokenize import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

nltk.download('punkt')

def preprocess_text_nltk(text):
    tokens = word_tokenize(text.lower())
    return tokens

def extract_features_nltk(text_data):
    vectorizer = CountVectorizer(tokenizer=preprocess_text_nltk)
    X = vectorizer.fit_transform(text_data)
    feature_names = vectorizer.get_feature_names()
    return X, feature_names


def AnalyseQuery(query):
    query_corpus = [
        "top performing mutual funds",
        "fund manager"
    ]
    X, feature_names = extract_features_nltk(query_corpus)

    n_topics = 2  # Assuming 2 main topics: top_funds, fund_manager
    lda_model = LatentDirichletAllocation(n_components=n_topics, random_state=42)
    lda_model.fit(X)

    tokens = preprocess_text_nltk(query)
    query_vec = lda_model.transform(vectorizer.transform([' '.join(tokens)]))
    dominant_topic = query_vec.argmax()

    # Generate response based on topic
    if dominant_topic == 0:
        return "top_funds"
    elif dominant_topic == 1:
        print("Query pertains to fund manager.")
        return "fund_manager"
    else:
        print("Unknown query topic.")

# %%
# Retrieval

def retrieve_top_performing_funds(chunks):
    all_funds_performance = {}
    for fund, data in chunks.items():
        returns = [float(row['Returns']) for row in data]
        average_return = sum(returns) / len(returns)
        all_funds_performance[fund] = average_return
    sorted_funds = sorted(all_funds_performance.items(), key=operator.itemgetter(1), reverse=True)
    top_funds = sorted_funds[:3]
    return top_funds

def retrieve_fund_manager(chunks):
    fund_managers = {}
    for fund, data in chunks.items():
        fund_manager = data[0]['Fund Manager']
        fund_managers[fund] = fund_manager
    return fund_managers

def retrieve_information(query, chunks):    
    if AnalyseQuery(query) == "top_funds":
        return retrieve_top_performing_funds(chunks)
    elif AnalyseQuery(query) == "fund_manager":
        return retrieve_fund_manager(chunks)

# %%
# Response Generation
def generate_response(query_type, retrieved_info):
    if query_type == "top_funds":
        response = "The top 3 performing mutual funds are:"
        for fund, returns in retrieved_info:
            response += f"\n- {fund}: {returns}%"
    elif query_type == "fund_manager":
        response = "Fund managers for the specified funds are:"
        for fund, manager in retrieved_info.items():
            response += f"\n- {fund}: {manager}"
    else:
        response = "Sorry, I couldn't understand the query."
    return response

# %%
def main():
    # load the data extracted form the PDF into CSV files
    funds_data = load_data_from_csv('funds_data.csv')

    # Chunk the document
    fundChunks = chunkByFundDetails(funds_data)
    fundPerformanceChunks, fundManagerChunks = chunkByFundPerformance(funds_data)

    # Example queries
    queries = [
        "What are the top performing mutual funds?",
        "Who is the fund manager of ICICI BlueChip Fund?"
    ]

    for query in queries:
        # Step 2: Analyze the query
        query_type = AnalyseQuery(query)

        # Step 3: Retrieve information based on query type
        if query_type == "top_funds":
            retrieved_info = retrieve_information(query_type, fundChunks)
        elif query_type == "fund_manager":
            retrieved_info = retrieve_information(query_type, fundManagerChunks)
        else:
            retrieved_info = None

        # Step 4: Generate response
        response = generate_response(query_type, retrieved_info)
        print(response)

if __name__ == "__main__":
    main()
